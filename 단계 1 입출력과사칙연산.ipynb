# %%
#1https://www.acmicpc.net/step/1

# %%
#2
for _ in range(2):
    print("강한친구 대한육군")
# Out:
# 강한친구 대한육군
# 강한친구 대한육군

# %%
#3
print("\\    /\\")
print(" )  ( \')")
print("(  /  )")
print(" \(__)|")
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %%
#4
print("|\_/|")
print('|q p|   /}')
print('( 0 )\"\"\"\\')
print('|"^"`    |')
print('||_/=\\\\__|')
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|

# %%
#5
a, b = map(int,input().split())
print(a+b)
# Out:
# 1 2
# 3

# %%
# 6
a, b = map(int,input().split())
print(a-b)
# Out:
# 3 2
# 1

# %%
#7
a, b = map(int, input().split())
print(a*b)
# Out:
# 3 4
# 12

# %%
#8
a, b = map(int, input().split())
print(a/b)
# Out:
# 4 5
# 0.8

# %%
#9
a, b = map(int, input().split())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
# Out:
# 7 3
# 10
# 4
# 21
# 2
# 1

# %%
#10
a = input()
id_list = a
if a in id_list :
    print(a+"??!")
# Out:
# joonas
# joonas??!

# %%
#11
a = int(input())
print(a-543)
# Out:
# 2541
# 1998

# %%
#12
A, B, C = map(int,input().split())
print((A+B)%C)
print(((A%C) + (B%C))%C)
print((A*B)%C)
print(((A%C) * (B%C))%C)
# Out:
# 5 8 4
# 1
# 1
# 0
# 0

# %%
#13 
a = int(input())
b = input()
print(a*int(b[-1]))
print(a*int(b[-2]))
print(a*int(b[-3]))
print(a*int(b))
# Out:
# 472
# 385
# 2360
# 3776
# 1416
# 181720

# %%
2541-1998
# Out:
# 543

# %%
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|
